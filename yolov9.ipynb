# %% [markdown]
# ## RUN THIS FOR VARIABLE REINITIALIZATION

# %%
import os
HOME = os.getcwd()
print(HOME)

# %cd {HOME}/yolov9
from roboflow import Roboflow
rf = Roboflow(api_key="1siqLpb2FMeu2XdJ7i4n")
project = rf.workspace("4d").project("ppe-4ngvv")
version = project.version(3)
dataset = version.download("yolov9")
# Out:
# /Users/richardpalabasan/Desktop/ppe
# /Users/richardpalabasan/Desktop/ppe/yolov9
# /Users/richardpalabasan/Desktop/ppe/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PPE-3 in yolov9:: 100%|██████████| 18570/18570 [00:01<00:00, 9445.10it/s]

# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %% [markdown]
# ## Requirements

# %% [markdown]
# Setting Home

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /Users/richardpalabasan/Desktop/ppe

# %% [markdown]
# Checks the installed libraries

# %%
# %pip freeze
# Out:
# absl-py==2.1.0
# albumentations==1.4.1
# appnope==0.1.4
# asttokens==2.4.1
# astunparse==1.6.3
# cachetools==5.3.3
# certifi==2023.7.22
# chardet==4.0.0
# charset-normalizer==3.3.2
# chex==0.1.85
# cloudpickle==3.0.0
# coloredlogs==15.0.1
# comm==0.2.2
# contourpy==1.2.0
# cycler==0.10.0
# debugpy==1.8.1
# decorator==5.1.1
# dm-tree==0.1.8
# etils==1.7.0
# executing==2.0.1
# filelock==3.13.1
# flatbuffers==24.3.7
# flax==0.8.2
# fonttools==4.50.0
# fsspec==2024.3.0
# gast==0.5.4
# gitdb==4.0.11
# GitPython==3.1.42
# google-auth==2.28.2
# google-auth-oauthlib==1.2.0
# google-pasta==0.2.0
# grpcio==1.62.1
# h5py==3.10.0
# humanfriendly==10.0
# idna==2.10
# imageio==2.34.0
# importlib_resources==6.3.1
# ipykernel==6.29.3
# ipython==8.22.2
# jax==0.4.25
# jaxlib==0.4.25
# jedi==0.19.1
# Jinja2==3.1.3
# joblib==1.3.2
# jupyter_client==8.6.1
# jupyter_core==5.7.2
# keras==3.0.5
# kiwisolver==1.4.5
# lazy_loader==0.3
# libclang==18.1.1
# Markdown==3.6
# markdown-it-py==3.0.0
# ...

# %% [markdown]
# Clones the respo of the original yolov9 and installs all its requirements

# %%
# !git clone https://github.com/WongKinYiu/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q

# %% [markdown]
# **OPTIONAL**

# %%
# %pip install torch torchvision torchaudio
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel

# %% [markdown]
# Install roboflow library

# %%
# %pip install -q roboflow #--use-deprecated=legacy-resolver

# %% [markdown]
# ## Weights Download

# %% [markdown]
# Download the weights (use !wget or !curl)

# %%
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c-converted.pt
# !curl https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e-converted.pt

"""
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c-converted.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e-converted.pt
"""

# %% [markdown]
# ## Dataset

# %% [markdown]
# Change directory into yolov9 to prepare for dataset download

# %%
# %cd {HOME}/yolov9
# Out:
# /Users/richardpalabasan/Desktop/ppe/yolov9
# /Users/richardpalabasan/Desktop/ppe/venv/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# Downloads/Access the roboflow dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="1siqLpb2FMeu2XdJ7i4n")
project = rf.workspace("4d").project("ppe-4ngvv")
version = project.version(5)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PPE-5 in yolov9:: 100%|██████████| 13378/13378 [00:01<00:00, 9222.77it/s]

# %% [markdown]
# ## Model Training

# %% [markdown]
# Train using converted yolov9 (reparameterized) or gelan weights

# %%
# %cd {HOME}/yolov9

# !python train.py \
--workers 8 --batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml

# %% [markdown]
# Train using yolov9

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--workers 8 --batch 16 --epochs 5 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/yolov9-c.pt \
--cfg models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /Users/richardpalabasan/Desktop/ppe/yolov9
# This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
# train_dual: weights=/Users/richardpalabasan/Desktop/ppe/weights/yolov9-c.pt, cfg=models/detect/yolov9-c.yaml, data=/Users/richardpalabasan/Desktop/ppe/yolov9/PPE-5/data.yaml, hyp=hyp.scratch-high.yaml, epochs=5, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=cpu, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLO 🚀 v0.1-71-gda2d6ba Python-3.11.5 torch-2.2.1 CPU
#
# ...

# %% [markdown]
# ## Model Conversions

# %% [markdown]
# Convert from PyTorch (.pt) to ONNX (.onnx)

# %%
# !python {HOME}/yolov9/export.py \
--data {HOME}/yolov9/PPE-2/data.yaml \
--weights {HOME}/yolov9/best.pt \
--include onnx --dynamic

# %% [markdown]
# Convert from PyTorch (.pt) to TensorFlow (.tf)

# %%
# !python {HOME}/yolov9/export.py \
--data {HOME}/yolov9/PPE-2/data.yaml \
--weights {HOME}/yolov9/best.pt \
--include tflite

# %% [markdown]
# ## Model Inference

# %%
# !python detect.py \
--img 96 --conf 0.1 --device cpu --source 0 --hide-conf \
--weights {HOME}/yolov9/best.pt \
--data {dataset.location}/data.yaml
